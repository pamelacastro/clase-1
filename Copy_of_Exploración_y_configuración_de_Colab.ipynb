# %% [markdown]
# <a href="https://colab.research.google.com/github/pamelacastro/clase-1/blob/main/Copy_of_Exploraci%C3%B3n_y_configuraci%C3%B3n_de_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importar librerias
# Para correr comando *linux*, anteponer el signo **!**
#
# ## Otros comandos
# Para cierto comandos como *cd* utilizar **%**

# %%
# !pwd
# Out:
# /content

# %%
# !ls
# Out:
# drive  sample_data

# %%
# !cd sample_data/
# Out:
# /bin/bash: line 1: cd: sample_data/: No such file or directory

# %%
# !pwd
# Out:
# /content/sample_data

# %%
# %cd sample_data/
# Out:
# [Errno 2] No such file or directory: 'sample_data/'
# /content/sample_data

# %% [markdown]
# Hola

# %%
# !pwd
# !ls
# Out:
# /content/sample_data
# anscombe.json		     california_housing_train.csv  mnist_train_small.csv
# california_housing_test.csv  mnist_test.csv		   README.md

# %%
# !pip install opencv-python

# %% [markdown]
# # Leer una imagen con OpenCV
#
# ## Cargar archivos locales en Colab
#
# 1.   Subir una imagen al entorno Colab
# 2.   Obtener su ubicacion
# 3.   Procesarla

# %%
# prompt: Crea un codigo para leer una imagen con OpenCV y graficar la imagen original junto con sus canales de color RGB con Matplotlib

import cv2
import matplotlib.pyplot as plt

# Cargar la imagen
image = cv2.imread('/content/arbol.jpeg')  # Reemplaza 'image.jpg' con el nombre de tu archivo

# Convertir la imagen de BGR a RGB (OpenCV lee imágenes en formato BGR)
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Obtener los canales de color
red_channel = image_rgb[:, :, 0]
green_channel = image_rgb[:, :, 1]
blue_channel = image_rgb[:, :, 2]

# Mostrar la imagen original y sus canales de color usando Matplotlib
plt.figure(figsize=(12, 8))

plt.subplot(2, 2, 1)
plt.imshow(image_rgb)
plt.title('Imagen original')

plt.subplot(2, 2, 2)
plt.imshow(red_channel, cmap='gray')
plt.title('Canal Rojo')

plt.subplot(2, 2, 3)
plt.imshow(green_channel, cmap='gray')
plt.title('Canal Verde')

plt.subplot(2, 2, 4)
plt.imshow(blue_channel, cmap='gray')
plt.title('Canal Azul')

plt.tight_layout()
plt.show()

# %%
# prompt: de la imagen anterior detecta las partes del arbol como tronco, ramas y hojas

import cv2
import numpy as np
import matplotlib.pyplot as plt

# Cargar la imagen
image = cv2.imread('/content/arbol.jpeg')  # Reemplaza 'image.jpg' con el nombre de tu archivo
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Convertir a espacio de color HSV
hsv = cv2.cvtColor(image_rgb, cv2.COLOR_RGB2HSV)

# Definir rangos de color para hojas (verde)
lower_green = np.array([35, 40, 40])
upper_green = np.array([85, 255, 255])

# Crear una máscara para las hojas
mask_hojas = cv2.inRange(hsv, lower_green, upper_green)

# Eliminar ruido de la máscara
kernel = np.ones((5,5),np.uint8)
mask_hojas = cv2.morphologyEx(mask_hojas, cv2.MORPH_OPEN, kernel)
mask_hojas = cv2.morphologyEx(mask_hojas, cv2.MORPH_CLOSE, kernel)


# Encontrar contornos de las hojas
contours_hojas, _ = cv2.findContours(mask_hojas, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# Dibujar contornos de hojas en la imagen original
image_hojas = image_rgb.copy()
cv2.drawContours(image_hojas, contours_hojas, -1, (0, 255, 0), 3)


# --- Detección del tronco (ejemplo básico, se puede mejorar) ---
# Convertir a escala de grises
gray = cv2.cvtColor(image_rgb, cv2.COLOR_RGB2GRAY)

# Aplicar un filtro gaussiano para reducir ruido
blurred = cv2.GaussianBlur(gray, (5, 5), 0)

# Detectar bordes con Canny
edges = cv2.Canny(blurred, 50, 150)

# Encontrar contornos de los objetos
contours, _ = cv2.findContours(edges, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# Buscar el contorno más grande (probable tronco)
trunk_contour = max(contours, key=cv2.contourArea)

# Dibujar el contorno del tronco en la imagen
image_tronco = image_rgb.copy()
cv2.drawContours(image_tronco, [trunk_contour], -1, (0, 0, 255), 3)


# Mostrar resultados
plt.figure(figsize=(12, 10))

plt.subplot(2, 2, 1)
plt.imshow(image_rgb)
plt.title('Imagen original')

plt.subplot(2, 2, 2)
plt.imshow(image_hojas)
plt.title('Hojas detectadas')

plt.subplot(2, 2, 3)
plt.imshow(image_tronco)
plt.title('Tronco detectado')

plt.subplot(2, 2, 4)
plt.imshow(mask_hojas, cmap='gray')
plt.title('Máscara de hojas')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Corregir errores con IA**

# %%
# prompt: operaciones matriciales

import numpy as np

# Ejemplo de matrices
matrix1 = np.array([[1, 2], [3, 4]])
matrix2 = np.array([[5, 6], [7, 8]])

# Suma de matrices
sum_matrix = matrix1 + matrix2
print("Suma de matrices:\n", sum_matrix)

# Resta de matrices
diff_matrix = matrix1 - matrix2
print("Resta de matrices:\n", diff_matrix)

# Multiplicación de matrices
product_matrix = np.dot(matrix1, matrix2)  # o matrix1 @ matrix2
print("Producto de matrices:\n", product_matrix)

# Multiplicación elemento a elemento
elementwise_product = matrix1 * matrix2
print("Producto elemento a elemento:\n", elementwise_product)

# Transpuesta de una matriz
transposed_matrix = matrix1.T
print("Transpuesta de la matriz:\n", transposed_matrix)

# Inversa de una matriz
try:
    inverse_matrix = np.linalg.inv(matrix1)
    print("Inversa de la matriz:\n", inverse_matrix)
except np.linalg.LinAlgError:
    print("La matriz no es invertible.")

# Determinante de una matriz
determinant = np.linalg.det(matrix1)
print("Determinante de la matriz:\n", determinant)
# Out:
# Suma de matrices:
#  [[ 6  8]
#  [10 12]]
# Resta de matrices:
#  [[-4 -4]
#  [-4 -4]]
# Producto de matrices:
#  [[19 22]
#  [43 50]]
# Producto elemento a elemento:
#  [[ 5 12]
#  [21 32]]
# Transpuesta de la matriz:
#  [[1 3]
#  [2 4]]
# Inversa de la matriz:
#  [[-2.   1. ]
#  [ 1.5 -0.5]]
# Determinante de la matriz:
#  -2.0000000000000004

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-14-d5df0069828e> in <cell line: 0>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.11/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      98 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      99   """Mount your Google Drive at the specified mountpoint path."""
# --> 100   return _mount(
#     101       mountpoint,
#     102       force_remount=force_remount,
#
# /usr/local/lib/python3.11/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     135   )
#     136   if ephemeral:
# --> 137     _message.blocking_request(
#     138         'request_auth',
#     139         request={'authType': 'dfs_ephemeral'},
#
# ...

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# Load an color image in grayscale
img = cv2.imread('/content/arbol.jpeg',0)
plt.imshow(img)
plt.show()

# %% [markdown]
# *Mejor resultado*

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# Load an color image in grayscale
img = cv2.imread('/content/descarga.jpeg',0)

# Convert the image from BGR to RGB
# (OpenCV reads images in BGR format, Matplotlib uses RGB)
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) # Assuming img is color image

plt.imshow(img_rgb) # Display the image with correct color format
plt.show()

# %% [markdown]
# # Integrar con Almacenamiento Drive

# %%
# Opcional / Si no funciona desde la barra de navegacion
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# # Monitizacion de recursos e Integracion con Github

# %%
# !nvidia-smi
# Out:
# Sun Mar  9 17:57:35 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   34C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...
